# %% [markdown]
# <a href="https://colab.research.google.com/github/Raihannpc/panen/blob/anggota-2/panen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sistem Pencatatan Hasil Panen Digital

def laporan(komoditas, jumlah, harga):
    total = jumlah * harga

    print("\n=== LAPORAN HASIL PANEN ===")
    print("Komoditas       :", komoditas)
    print("Jumlah panen    :", jumlah, "kg")
    print("Harga per kg    : Rp", harga)
    print("Total hasil     : Rp", total)
