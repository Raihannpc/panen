# %% [markdown]
# <a href="https://colab.research.google.com/github/Raihannpc/panen/blob/main/panen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sistem Pencatatan Hasil Panen Digital

def input_data():
    print("=== INPUT DATA HASIL PANEN ===")

    komoditas = input("Nama komoditas: ")
    jumlah = float(input("Jumlah hasil panen (kg): "))
    harga = float(input("Harga per kg (Rp): "))

    return komoditas, jumlah, harga
